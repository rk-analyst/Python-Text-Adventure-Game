# %% [markdown]
# # Text Based Adventure Game - Cinderella Retold
#
# This text adventure game is based on the classic fairytale - **Cinderella**, written by the acclaimed French author, Charles Perrault.
#
# ## Storyline
#
# Until her mother passes away, Cinderella lives happily with her parents. After her mother's demise, Cinderella's pained father remarries a cold, cruel woman who has two daughters. They force Cinderella to do everything for them. <br>
# One day, the entire town receives an invitation to a ball at the palace. To prevent Cinderella from coming to the ball, her stepmother hands her a big list of chores to be done, which makes Cinderella extremely disappointed. Suddenly, a fairy godmother appears and helps Cinderella get to the ball. Cinderella and the Prince dance at the ball, where he falls in love with her. She sprints as quickly as she can at midnight, leaving her glass slipper behind. <br>
# The prince goes to every house in the kingdom, tests the shoe on a lot of different women, and then decides to marry the woman whose feet the shoe fits (Perrault & Brown, 1954).<br>
# Few situations for the alternative plot lines have been referenced from an online game website (Davey, 2017).
#
# ### APA References
#
# 1. Cel. (2014, July 18). ipython notebook clear cell output in code. Stack Overflow. Retrieved January 29, 2023, from https://stackoverflow.com/questions/24816237/ipython-notebook-clear-cell-output-in-code
#
# 2. Davey, E. (2017, September 11). Cinderella Retold- Alternative Plot-lines - Play online at textadventures.co.uk. Cinderella Retold- Alternative Plot-lines - Play Online at textadventures.co.uk. Retrieved January 27, 2023, from https://textadventures.co.uk/games/view/mxcDXWKgS06zvX1QM4uMbg/cinderella-retold-alternative-plot-lines
#
# 3.  Dirk, S. (2012, June 19). how to slow print text? - Raspberry Pi Forums. How to Slow Print Text? - Raspberry Pi Forums. Retrieved January 25, 2023, from https://forums.raspberrypi.com/viewtopic.php?t=136516
#
# 4. Fosmark, E. (2009, February 4). How do I make a time delay? Stack Overflow. Retrieved January 29, 2023, from https://stackoverflow.com/questions/510348/how-do-i-make-a-time-delay
#
# 5. Perrault C. & Brown M. (1954). Cinderella; or the little glass slipper. Charles Scribner's Sons.
#
# 6. Williams, M. (2015, May 22). Add colour to text in python. Add Colour to Text in Python. Retrieved January 29, 2023, from https://ozzmaker.com/add-colour-to-text-in-python/
#
#
# ## Game objective
#
# This game traverses Cinderella’s quest of finding her happily ever after. Through a series of situations, the player can explore alternative plot-lines and subsequent endings based on different decisions and choices.
#
# ## Possible bugs
#
# - For some situations, if the player presses 'Enter' instead of any other key, Python automatically chooses option 1. However, for most situations, it requests the user to give a valid input as defined through the if-elif-else clause.
#
# -------

# %%
#Importing required modules for our code
import time                                     # (Fosmark, 2009)
from IPython.display import clear_output        # (Cel, 2014)

#------------------------------------------ DEFINING ALL FUNCTIONS ------------------------------------------#


# Defining function intro to introduce the game to the user
def intro():
    '''Introduces the player to the storyline'''   # Docstring for the function

# Text to be displayed when intro function is run. The heading is displayed in bold (Williams, 2015).  
# The remaining text is printed slowly based on the for loop below.

    print("\n\t \033[1mIntroduction:\033[0m")
    sentence = (""" 
Cinderella lives in a beautiful house with her father and mother. 

One day her mother dies and after a few days her father remarries a snobbish woman who has two ugly daughters.

He soon leaves on a voyage as a merchant to make some money. She is now left under the care of her evil stepmom 
and step sisters who mistreat her and make her do all the chores of the house.

Cinderella yearns to lead a better life for which she needs your help.
    """)

# Printing one character at a time slowly based on the sleep time called from time module(Dirk, 2012).
# Please see APA references in introduction above for full citation.

    for s in sentence:                       # looping for each character at a time 
        print(s, end = '', flush = True)     # print each character, continuing on same line, flushing internal buffer
        time.sleep(0.02)
    print()                                  # go to new line
    
    
# Defining function rules to introduce the rules to the user
def rules():
    '''Introduces the player to the rules of the game'''     # Docstring for the function

# Text to be displayed when intro function is run. The heading is displayed in bold (Williams, 2015).  
# The remaining text is printed slowly based on the for loop below.
   
    print("\n\t \033[1mRules:\033[0m")
    sentence2 = (""" 
You will begin with a situation which will require you to make a choice between options. 

Based on your choices and decisions, the game will progress to different plot lines. 

So let's get going and see if you can help Cinderella find her happily ever after!!
    """)

# Printing one character at a time slowly based on the sleep time called from time module(Dirk, 2012).
# Please see APA references in introduction above for full citation.

    for s in sentence2:                       # looping for each character at a time 
        print(s, end = '', flush = True)      # print each character, continuing on same line, flushing internal buffer
        time.sleep(0.02)
    print()                                   # go to new line
    
    input(prompt = 'Press enter to continue. \n')
 

 # Clearing the screen using clear_output function from IPython.display module (Cel, 2014). 
 # Please see APA references in introduction above for full citation.

def clear_screen():
    '''Clears the current output on the screen'''     # Docstring for the function
    clear_output(wait = False)


# Defining function start to begin the game 
def start():
    '''This function leads the user to the first stage of the game'''  # Docstring for the function
   
    # Displaying the options which the player has to pick to proceed in the game
    print("""
    Having being left with her step-mother and sisters who consider her their servant, Cinderella: 
    
    1. Obeys and does everything 
    2. Stands up for herself and refuses 
    """)
    
# Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
    
    while True :
        # storing user input in variable ch1
        ch1 = input(prompt = 'What does she do? \n >')
        
        # if player picks option1 or the word 'obeys', the screen is cleared and the obeys function is called
        if ch1 == '1' or ch1.casefold() == 'obeys':
            clear_screen()  
            obeys()         
            break  # breaking out of the loop on valid user input
        
        # if player picks option2 or the words in the list, the screen is cleared and the refuses function is called
        elif ch1 == '2' or ch1.casefold() in ['stands up', 'refuses']:
            clear_screen()
            refuses()
            break   # breaking out of the loop on valid user input
        
        # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
        else:
            print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")


# Defining the obeys function to move to the next stage in the game 
def obeys():
    '''If the player picks option1 in the start phase, this function is called upon'''  # Docstring for the function
    
    # instantiating variable s3 for printing text slowly by iterating characters using a for loop
    s3= ("\nCut to few years later...")
 

    # Printing one character at a time slowly based on the sleep time called from time module(Dirk, 2012).
    # Please see APA references in introduction above for full citation.


    for s in s3:                               # looping for each character at a time 
        print(s, end = '', flush = True)       # print each character, continuing on same line, flushing internal buffer
        time.sleep(0.02)
    print()                                    # go to new line
    
    # Displaying the options which the player has to pick to proceed in the game
    print("""
    An announcement is made by the king of the land that a ball is being organized where all the
    young maidens in the town are invited. 
    
    At the ball, the prince, who is still a bachelor, will choose a beautiful bride for himself.
    
    Even before Cinderella can think about going to the ball, her evil stepmother hands her a huge list of 
    things to be done before they get back so that she is never able to make it to the ball. 
    
    Cinderella is :
    
    1. Sad about being forced to stay back
    2. Relieved that she finally has a night to herself 
    """) 
# Creating a while loop with nested if-else statements to request user input, and move to the next stage based on the same     
    while True :
        # storing user input in variable ob1
        ob1 = input(prompt = 'How does Cinderella feel? \n >')
        
        # if player picks option1 or a word in the list, the screen is cleared and text is printed for next input
        if ob1 == '1' or ob1.casefold() in ['sad', 'forced', 'stay back']:
            clear_screen()
            print("""
    The much awaited day of the ball arrives and the stepmother and stepsisters are all dressed up to go to 
    the ball to impress the prince. 

    Cinderella sobbingly completes the list of tasks, wishing that she could also get a chance to go
    to the ball.

    Just then, she hears a knock at the door to find a gleaming angel-like woman, who smiles at her and says 
    that she is here to help her. 

    Cinderella is : 

    1. Alarmed to see her and she faints
    2. Glad to see her and asks for help
            
            """)
            # Creating a while loop with nested if-else statements to request user input, and move to the next stage based on the same 
            while True:
                # storing user input in variable choice1
                choice1 = input(prompt = 'What is her reaction? \n >')
                
                # if player picks option1 or a word in the list, the screen is cleared and text is printed for next input
                if choice1 == '1' or choice1.casefold() in ['alarmed', 'faints']:
                    print("""
        Cinderella remains unconscious for hours- waking up having missed the Ball completely.

        1. Her step family returns and she continues to serve them
        2. One of her step-sisters marries the prince
                    """)
                    
        # Using a try-except clause for error control - user is asked to enter a valid input if not done in the beginning    
                    try:
                        # Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
                        while True:
                            # storing user input in variable option1
                            option1 =  input(prompt = 'Enter your choice. \n >')
                            
                            # if player picks either of the options, they lose the game
                            if option1 == '1' or option1.casefold() in 'serve'or option1 == '2' or option1.casefold() in 'marries':
                                time.sleep(2)
                                clear_screen()
                                print ("""
            \n \033[1;31m
            ☠️ Cinderella lives happily NEVER after ☠️
            \033[0;0m
                                """)
                                lose()           # calling lose function
                                time.sleep(2)
                                replay_lose()    # asking player if they want to replay
                                break       # breaking out of the loop on valid user input

                            # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                            else:
                                print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead. ")
                        break      # breaking out of the loop on valid user input       

                    # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                    except:
                        print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")        

                # if player picks option2 or the words in the list, the glad() function is called 
                elif choice1 == '2' or choice1.casefold() in ['glad', 'help']:
                    glad()
                    break   # breaking out of the loop on valid user input
                    
                # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                else:
                    print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")
                    
            break   # breaking out of the loop on valid user input
            
        # if player picks option2 or the word 'relieved', the screen is cleared and text is printed for next input 
        elif ob1 == '2' or ob1.casefold() == 'relieved':
            clear_screen()
            print("""
        The much awaited day of the ball arrives and the stepmother and stepsisters are all dressed up to go to 
        the ball to impress the prince. 

        Cinderella quickly finishes all the tasks assigned to her and sits down by the fireplace with the 
        hope that she can atleast enjoy a good meal and read her favourite book.

        Just then, she hears a knock at the door to find a gleaming angel-like woman, who smiles at her and 
        says that she is here to help her.

        Cinderella is :

        1. Upset on being disturbed and shoos the lady away
        2. Glad to see her and asks for help
            
            """)
            # Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
            while True :
                # storing user input in variable choice1
                choice1 = input(prompt = 'What is her reaction? \n >')
                
                # if player picks option1 or a word in the list, they lose the game
                if choice1 == '1' or choice1.casefold() in ['upset', 'disturbed', 'shoos']:
                    print("\n Oh oh... I'm afraid for you....")
                    time.sleep(3)
                    clear_screen()
                    print("""
        The fairy godmother is infuriated on being stormed off and Cinderella's joy is short-lived.
        \n \033[1;31m
        ☠️ Her step family returns soon and continues to pile torture on Cinderella. 
        She lives UNHAPPILY ever after ☠️
        \033[0;0m
                    """)
                    lose()              # calling lose function
                    time.sleep(2)
                    replay_lose()       # asking player if they want to replay
                    break      # breaking out of the loop on valid user input
                
                # if player picks option2 or the words in the list, the glad() function is called 
                elif choice1 == '2' or choice1.casefold() in ['glad', 'help']:
                    glad()
                    break       # breaking out of the loop on valid user input
                    
                # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                else:
                    print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")            
            break      # breaking out of the loop on valid user input
        
        # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
        else:
            print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")

# Defining the glad function to move to the next stage in the game
def glad():
    '''If the player picks option2 in the obeys phase, this function is called upon'''  # Docstring for the function
    
    # Clearing the screen using clear_screen function
    clear_screen()
    
    # instantiating lists for Cinderella's before and after transformation
    before_transform_lst = ['tattered dress', 'shabby sandals', 'pumpkin']
    after_transform_lst = ['beautiful gown', 'sparkling glass slippers','elegant coach' ]
    
    # Using a for loop to iterate and display Cinderella's transformation
    print("The fairy godmother waved her wand and transformed Cinderella's", end = ' ') 
    
    for thing in before_transform_lst:
        print(thing, end = ', ' )

    print("into a", end = ' ')
    
    for thing in after_transform_lst:
        print(thing, end = ', ' )

    print("respectively.")
    
    # Displaying text for next user input to proceed in the game
    print("""
    
    She however warned Cinderella, that the magical spell would wear off as soon as the clock struck midnight.
    
    Cinderella:
    
    1. Obliges and is whisked away to the ball
    2. Trips and her glass slippers shatter

    """) 
    
    # Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
    while True :
        # storing user input in variable g1
        gl = input(prompt = 'What happens next? \n >')
        
        # if player picks option1 or a word in the list, the screen is cleared and text is printed for next input
        if gl == '1' or gl.casefold() in ['obliges', 'whisked', 'ball']:
            print("""
    At the ball, the prince is mesmerized by Cinderella’s beauty and chooses her to dance with.

    Everyone in the crowd including her step-family stands amazed. Soon, the clock strikes 12 ....

    1. Cinderella rushes down the stairs while losing a slipper
    2. Cinderella continues to dance way past 12

            """) 
            # Creating a while loop with nested if-else statements to request user input, and move to the next stage based on the same 
            while True:
                # storing user input in variable choice
                choice = input(prompt = 'When the clock strikes 12, Cinderella: \n >')
                
                # if player picks option1 or a word in the list, the screen is cleared and text is printed for next input
                if choice == '1' or choice.casefold() in ['rushes', 'stairs', 'losing', 'slipper']:
                    print("""
        The prince next day comes to the town in search of the maiden and the owner of the glass slipper.

        The slipper fits:

        1. Cinderella’s foot
        2. Her ugly step sister’s foot
                    
                    """)
                    # Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
                    while True:
                        # storing user input in variable choice1
                        choice1 = input(prompt = 'Whose foot does the slipper fit? \n >')
                        
                        # if player picks option1 or a word in the list, they win the game
                        if choice1 == '1' or choice1.casefold() in ['cinderella', 'cinderella\'s']:
                            time.sleep(2)
                            clear_screen()
                            print("""
            \n \033[1;32m
            💒 The prince and Cinderella get married and they live HAPPILY ever after!! 💒
            \033[0;0m
                            """)
                            win()                  # calling win function
                            time.sleep(2) 
                            replay_win()           # asking player if they want to replay
                            break      # breaking out of the loop on valid user input
                        
                        # if player picks option2 or the words in the list, they lose the game
                        elif choice1 == '2' or choice1.casefold() in ['step sister', 'step sister\'s', 'ugly step sister\'s', 'ugly step sister' ]:
                            print("\nOh dear...")
                            time.sleep(2)
                            clear_screen()
                            print("""\n \033[1;31m
            🥴 The prince marries her ugly sister and Cinderella lives UNHAPPILY ever after. 🥴
                            \033[0;0m""")
                            lose()               # calling lose function
                            time.sleep(2)
                            replay_lose()        # asking player if they want to replay
                            break       # breaking out of the loop on valid user input
                        
                        # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                        else:
                            print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")
                    break    # breaking out of the loop on valid user input
                
                # if player picks option2 or the words in the list, they lose the game
                elif choice == '2' or choice.casefold() in ['continues', 'dance', 'past']:
                    time.sleep(1.5)
                    clear_screen()
                    print("Alas, poor Cinderella .....")
                    time.sleep(2)
                    print("""\n \033[1;31m
            😮‍💨 The spell wears off and Cinderella is back in her rags. 
            Everyone starts laughing at the Prince for dancing with a poor girl which embarrasses him. 
            He prosecutes Cinderella to imprisonment and she lives happily NEVER after. 😮‍💨
                    \033[0;0m""")
                    lose()             # calling lose function
                    time.sleep(2)
                    replay_lose()      # asking player if they want to replay
                    break       # breaking out of the loop on valid user input
                
                # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                else:
                    print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")
             
            break        # breaking out of the loop on valid user input
        
        # if player picks option2 or the words in the list, they lose the game
        elif gl == '2' or gl.casefold() in ['trips', 'shatter','glass', 'slippers']:
            time.sleep(1.5)
            clear_screen()
            print("\nOuch! That hurts...")
            time.sleep(2)
            print("""
            \n \033[1;31m
            🩸 Cinderella is rushed to the hospital and doesn't get to meet the prince.
            She lives UNHAPPILY ever after. 🩸
            \033[0;0m
            """)
            lose()                   # calling lose function
            time.sleep(2)
            replay_lose()            # asking player if they want to replay
            break        # breaking out of the loop on valid user input
        
        # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
        else:
            print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")
    
            
            
# Defining the refuses function to move to the next stage in the game    
def refuses():
    '''If the player picks option2 in the start phase, this function is called upon'''  # Docstring for the function
    
    print("""
    Geeez.... Cinderella gets thrown out of the house for disobeying her step mother. 
    
    Cinderella :
    
    1. Chooses to live on the bench of the park forever
    2. Becomes a caretaker of 4 children of a widowed young father.
    
    """)
    
    # Creating a while loop with nested if-else statements to request user input, and move to the next stage based on the same 
    while True :
        # storing user input in variable ref1
        ref1 = input(prompt = 'Where does Cinderella go? \n >')
        
        # if player picks option1 or a word in the list, they lose the game
        if ref1 == '1' or ref1.casefold() in ['bench', 'park']:
            time.sleep(1.5)
            clear_screen()
            print("""\n \033[1;31m
            ☠️ Cinderella struggles to make ends meet and lives UNHAPPILY ever after. ☠️
            \033[0;0m""")
            lose()                 # calling lose function
            time.sleep(2)
            replay_lose()          # asking player if they want to replay
            break       # breaking out of the loop on valid user input
            
        # if player picks option2 or the words in the list, text is printed for the next user input
        elif ref1 == '2' or ref1.casefold() == 'caretaker':
            print("""
    Cinderella settles into her job and starts taking a liking towards it. As days progress, she:
    
    1. Takes over more jobs as a caretaker for different families
    2. Falls in love with the father of the 4 children
    
    """)
            # Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
            while True :
                # storing user input in variable ct1
                ct1 = input(prompt = 'What does she do next? \n >')
                
                # if player picks option1 or a word in the list, they win the game
                if ct1 == '1' or ct1.casefold() in ['more jobs', 'caretaker', 'different families']:
                    time.sleep(1.5)
                    clear_screen()
                    print("""
            \n \033[1;32m
            🎉 Cinderella leads the rest of her life fulfilled by her career and lives HAPPILY ever after. 🎉
            \033[0;0m
                    """)
                    win()                  # calling win function
                    time.sleep(2)
                    replay_win()           # asking player if they want to replay
                    break           # breaking out of the loop on valid user input
            
                # else if player picks option2 or a word in the list, they win the game
                elif ct1 == '2' or ct1.casefold() in ['love', 'father']:
                    time.sleep(1.5)
                    clear_screen()
                    print("""
            \n \033[1;32m
            👩‍❤️‍👨 Cinderella finds a loving family in them, marries the father and lives HAPPILY ever after. 👩‍❤️‍👨
            \033[0;0m
                    """)
                    win()                # calling win function
                    time.sleep(2)
                    replay_win()         # asking player if they want to replay
                    break         # breaking out of the loop on valid user input
                
                # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                else:
                    print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")
         
            break              # breaking out of the loop on valid user input
        
        # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
        else:
            print("Sorry, that's an invalid input. Try entering the number 1 or 2 instead.")

# Defining the replay_lose function which is called when the player loses and wants to play the game again. 
# The player is first asked if they would like to play again. 
            
def replay_lose():
    '''This function is run if a player loses and wants to play the game again'''  # Docstring for the function
    
    print("\nYou seem disappointed....")
    
    yes_lst = ['y', 'yes', 'ya', 'yeah', 'yea']
    no_lst = ['n', 'no', 'na', 'nah', 'nay', 'nope']
    
    # Creating a while loop with nested if-else statements to request user input, and move to the next stage based on the same 
    while True:
        # storing user input in variable replay
        replay = input(prompt = "\nWould you like to play again? (Y/N) \n >")
        
        # if player chooses to replay the game, they are asked if they want to read intro and rules again
        if replay.casefold() in yes_lst:
            print("\nYay, that's awesome!")
            
            # Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
            while True:
                # storing user input in variable again
                again = input(prompt = "\nWould you like to read the introduction and rules again? (Y/N) \n >")
            
                # if player chooses to read the intro and rules again, intro() and rules() functions are run before start()
                if again.casefold() in yes_lst:
                    print("\nHere you go!")
                    time.sleep(1)
                    clear_screen()
                    intro()
                    time.sleep(2)
                    rules()
                    clear_screen()
                    start()
                    break                # breaking out of the loop on valid user input
               
                # if player chooses not to read the intro and rules again, the screen is cleared and start() function is run 
                elif again.casefold() in no_lst:
                    print("\nOkay! Let's get to business straight away!")
                    time.sleep(1)
                    clear_screen()
                    start()
                    break               # breaking out of the loop on valid user input
                    
                # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                else:
                    print("Sorry, that's an invalid input. Try entering the alphabets Y or N instead.")

            break                      # breaking out of the loop on valid user input
        
        elif replay.casefold() in no_lst:
            print("\nNice try with the previous game, btw! Thanks for playing! Have a great day!")
            break                      # breaking out of the loop on valid user input
        
        # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
        else:
            print("Sorry, that's an invalid input. Try entering the alphabets Y or N instead.")
        
# Defining the replay_win function which is called when the player wins and wants to play the game again. 
# The player is first asked if they would like to play again. 

def replay_win():
    '''This function is run if a player wins and wants to play the game again to explore a different
    plotline'''  # Docstring for the function
    
    print("Great Job !!!")
    
    yes_lst = ['y', 'yes', 'ya', 'yeah', 'yea']
    no_lst = ['n', 'no', 'na', 'nah', 'nay', 'nope']
    
    # Creating a while loop with nested if-else statements to request user input, and move to the next stage based on the same 
    while True:
        # storing user input in variable replay
        replay = input(prompt = "\nWould you like to explore a different plotline? (Y/N) \n >")
        
        # if player chooses to replay the game, they are asked if they want to read intro and rules again
        if replay.casefold() in yes_lst:
            print("\n Yay, that's awesome!")
            
            # Creating a while loop with if-else statements to request user input, and move to the next stage based on the same 
            while True:
                # storing user input in variable again
                again = input(prompt = "\nWould you like to read the introduction and rules again? (Y/N) \n >")
            
                # if player chooses to read the intro and rules again, intro() and rules() functions are run before start()
                if again.casefold() in yes_lst:
                    print("\n Here you go!")
                    time.sleep(1)
                    clear_screen()
                    intro()
                    time.sleep(2)
                    rules()
                    clear_screen()
                    start()
                    break                  # breaking out of the loop on valid user input
                
                # if player chooses not to read the intro and rules again, the screen is cleared and start() function is run 
                elif again.casefold() in no_lst:
                    print("\n Okay! Let's get to business straight away!")
                    time.sleep(1.5)
                    clear_screen()
                    start()
                    break                 # breaking out of the loop on valid user input
                    
                # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
                else:
                    print("Sorry, that's an invalid input. Try entering the alphabets Y or N instead.")

            break                 # breaking out of the loop on valid user input
        
        elif replay.casefold() in no_lst:
            print("\n Thanks for playing! Have a great day!")
            break                # breaking out of the loop on valid user input
        
        # if player enters an invalid input, the while loop iterates continuously until user gives a valid input
        else:
            print("Sorry, that's an invalid input. Try entering the alphabets Y or N instead.")
          
        
    
# Defining the lose function which is called when the game is won by the player                   
def win():
    '''This function is run when the player wins the game'''  # Docstring for the function
    
    # ASCII Art to be printed on winning
    print("""
    \033[1;32m
     ▄         ▄  ▄▄▄▄▄▄▄▄▄▄▄  ▄         ▄       ▄         ▄  ▄▄▄▄▄▄▄▄▄▄▄  ▄▄        ▄  ▄ 
▐░▌       ▐░▌▐░░░░░░░░░░░▌▐░▌       ▐░▌     ▐░▌       ▐░▌▐░░░░░░░░░░░▌▐░░▌      ▐░▌▐░▌
▐░▌       ▐░▌▐░█▀▀▀▀▀▀▀█░▌▐░▌       ▐░▌     ▐░▌       ▐░▌ ▀▀▀▀█░█▀▀▀▀ ▐░▌░▌     ▐░▌▐░▌
▐░▌       ▐░▌▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌       ▐░▌     ▐░▌     ▐░▌▐░▌    ▐░▌▐░▌
▐░█▄▄▄▄▄▄▄█░▌▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌   ▄   ▐░▌     ▐░▌     ▐░▌ ▐░▌   ▐░▌▐░▌
▐░░░░░░░░░░░▌▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌  ▐░▌  ▐░▌     ▐░▌     ▐░▌  ▐░▌  ▐░▌▐░▌
 ▀▀▀▀█░█▀▀▀▀ ▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌ ▐░▌░▌ ▐░▌     ▐░▌     ▐░▌   ▐░▌ ▐░▌▐░▌
     ▐░▌     ▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌▐░▌ ▐░▌▐░▌     ▐░▌     ▐░▌    ▐░▌▐░▌ ▀ 
     ▐░▌     ▐░█▄▄▄▄▄▄▄█░▌▐░█▄▄▄▄▄▄▄█░▌     ▐░▌░▌   ▐░▐░▌ ▄▄▄▄█░█▄▄▄▄ ▐░▌     ▐░▐░▌ ▄ 
     ▐░▌     ▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌     ▐░░▌     ▐░░▌▐░░░░░░░░░░░▌▐░▌      ▐░░▌▐░▌
      ▀       ▀▀▀▀▀▀▀▀▀▀▀  ▀▀▀▀▀▀▀▀▀▀▀       ▀▀       ▀▀  ▀▀▀▀▀▀▀▀▀▀▀  ▀        ▀▀  ▀ 
                                                                                                                                                                                                                         
    \033[0;0m
    """)

# Defining the lose function which is called when the game is lost by the player
def lose():
    '''This function is run when the player loses the game'''  # Docstring for the function
    
    # ASCII Art to be printed on losing
    print("""
    \033[1;31m
     ▄         ▄  ▄▄▄▄▄▄▄▄▄▄▄  ▄         ▄       ▄            ▄▄▄▄▄▄▄▄▄▄▄  ▄▄▄▄▄▄▄▄▄▄▄  ▄▄▄▄▄▄▄▄▄▄▄  ▄      
▐░▌       ▐░▌▐░░░░░░░░░░░▌▐░▌       ▐░▌     ▐░▌          ▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌▐░▌     
▐░▌       ▐░▌▐░█▀▀▀▀▀▀▀█░▌▐░▌       ▐░▌     ▐░▌          ▐░█▀▀▀▀▀▀▀█░▌▐░█▀▀▀▀▀▀▀▀▀ ▐░█▀▀▀▀▀▀▀▀▀ ▐░▌     
▐░▌       ▐░▌▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌          ▐░▌       ▐░▌▐░▌          ▐░▌          ▐░▌     
▐░█▄▄▄▄▄▄▄█░▌▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌          ▐░▌       ▐░▌▐░█▄▄▄▄▄▄▄▄▄ ▐░█▄▄▄▄▄▄▄▄▄ ▐░▌     
▐░░░░░░░░░░░▌▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌          ▐░▌       ▐░▌▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌▐░▌     
 ▀▀▀▀█░█▀▀▀▀ ▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌          ▐░▌       ▐░▌ ▀▀▀▀▀▀▀▀▀█░▌▐░█▀▀▀▀▀▀▀▀▀ ▐░▌     
     ▐░▌     ▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌          ▐░▌       ▐░▌          ▐░▌▐░▌           ▀      
     ▐░▌     ▐░█▄▄▄▄▄▄▄█░▌▐░█▄▄▄▄▄▄▄█░▌     ▐░█▄▄▄▄▄▄▄▄▄ ▐░█▄▄▄▄▄▄▄█░▌ ▄▄▄▄▄▄▄▄▄█░▌▐░█▄▄▄▄▄▄▄▄▄  ▄      
     ▐░▌     ▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌     ▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌▐░▌     
      ▀       ▀▀▀▀▀▀▀▀▀▀▀  ▀▀▀▀▀▀▀▀▀▀▀       ▀▀▀▀▀▀▀▀▀▀▀  ▀▀▀▀▀▀▀▀▀▀▀  ▀▀▀▀▀▀▀▀▀▀▀  ▀▀▀▀▀▀▀▀▀▀▀  ▀      
     \033[0;0m                                                                                                   
    """)

            



    


    
#------------------------------------------ STARTING THE GAME ------------------------------------------#

# Asking the player to input their name and storing it in the variable 'name'
name = input(prompt = """Hello there!
Before we get started, please tell us your name. \n""")

# Capitalizing the first letter of their name and welcoming them to the game
name2 = name.capitalize()

print(f"\nHi, {name2}! \nWelcome to the text-adventure game: \033[1mCINDERELLA RETOLD 👸🏼👠🕛🎃\033[0m")


# Calling all functions to start the game, including animation and transition effects
time.sleep(2.5)
clear_screen()
intro()
time.sleep(1.5)
rules()
clear_screen()
start()
